# %% [markdown]
# ### Upgrade pip to Latest Version

# %%
# !pip install --upgrade pip

# %% [markdown]
# ### Install Required Libraries: numpy, opencv-python, and tqdm
# This command installs three essential Python libraries:
#
# - numpy: A fundamental package for scientific computing in Python, primarily used for array operations and mathematical functions.
# - opencv-python: A library that allows for image and video processing, computer vision tasks, and deep learning applications.
# - tqdm: A library used to display progress bars in loops, helping track the progress of time-consuming operations.
#
# These libraries are required to perform operations such as image manipulation, data processing, and progress monitoring in the following sections of the project.

# %%
# !pip install numpy opencv-python tqdm
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Install Core Libraries and Dependencies
# This command installs essential libraries for the project:
#
# - numpy: A powerful library for numerical computing in Python, providing support for arrays and matrix operations.
# - torch: The core library for PyTorch, used for building and training deep learning models.
# - torchvision: A package that provides utilities for image processing and computer vision tasks, including dataset loading and transformation functions.
# - pathlib: A library for working with file system paths in an object-oriented way, making it easier to handle file paths across different platforms.

# %%
# Core libraries
# !pip install numpy torch torchvision

# For managing datasets and transformations
# !pip install torchvision

# For working with file paths
# !pip install pathlib
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Install OpenCV Library
# This command installs the opencv-python package, which is a Python wrapper for the OpenCV library. OpenCV (Open Source Computer Vision Library) is used for computer vision tasks, such as image processing, object detection, and video analysis. It provides tools to load, modify, and save images or video frames.

# %%
# !pip install opencv-python
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Install Torchviz Library
# The torchviz library is a Python package used to visualize PyTorch models. It generates graphs that represent the computational flow of tensors through the layers of a PyTorch model. This is particularly useful for understanding the structure of a neural network, debugging, and explaining model architectures.

# %%
# !pip install torchviz
# Out:
# ...
#      ---------------------------------------- 0.0/47.1 kB ? eta -:--:--
#      ----------------- ---------------------- 20.5/47.1 kB ? eta -:--:--
#      ----------------- ---------------------- 20.5/47.1 kB ? eta -:--:--
#      ------------------------ ------------- 30.7/47.1 kB 163.8 kB/s eta 0:00:01
#      --------------------------------- ---- 41.0/47.1 kB 217.9 kB/s eta 0:00:01
#      -------------------------------------- 47.1/47.1 kB 196.2 kB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Install Torchsummary Library
# The torchsummary library provides a summary of the model architecture, including the number of parameters and layer outputs. This summary helps in understanding the model’s structure and can be helpful for debugging and optimization. It is widely used in conjunction with PyTorch to display a model's architecture in a clear and concise format.

# %%
# !pip install torchsummary
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Install Torchviz Library
# The torchviz library is used to visualize the computational graph of a PyTorch model. It helps in visualizing the structure of the neural network and the flow of data through it, making it easier to understand and debug complex models. Torchviz generates a graph that represents the model’s operations and can be saved as a .pdf or .png file.

# %%
# !pip install torchviz
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Print System PATH Environment Variable
#
# This code snippet is used to print the PATH environment variable of the system. The PATH variable contains a list of directories that are searched for executable files. By printing this variable, you can check which directories are included in the system's environment search path.
#
# This can help you ensure that all required executables (such as Python or specific tools) are correctly accessible.

# %%
import os
print(os.environ['PATH'])
# Out:
# C:\WINDOWS\system32;C:\WINDOWS;C:\WINDOWS\System32\Wbem;C:\WINDOWS\System32\WindowsPowerShell\v1.0\;C:\WINDOWS\System32\OpenSSH\;C:\Program Files (x86)\National Instruments\Shared\LabVIEW CLI;C:\Program Files\MATLAB\R2023a\runtime\win64;C:\Program Files\MATLAB\R2023a\bin;C:\Program Files\HP\HP One Agent;C:\Program Files\MySQL\MySQL Server 8.0\bin;C:\WINDOWS\system32;C:\WINDOWS;C:\WINDOWS\System32\Wbem;C:\WINDOWS\System32\WindowsPowerShell\v1.0\;C:\WINDOWS\System32\OpenSSH\;D:\windows_10_cmake_Release_Graphviz-12.2.1-win64\Graphviz-12.2.1-win64\bin;C:\Users\ARAVINDA S H\AppData\Local\Programs\Python\Python310\Scripts\;C:\Users\ARAVINDA S H\AppData\Local\Programs\Python\Python310\;C:\Users\ARAVINDA S H\AppData\Local\Programs\Python\Python39-32\Scripts\;C:\Users\ARAVINDA S H\AppData\Local\Programs\Python\Python39-32\;C:\Program Files\MySQL\MySQL Shell 8.0\bin\;C:\Users\ARAVINDA S H\AppData\Local\Programs\Python\Python311\Scripts\;C:\Users\ARAVINDA S H\AppData\Local\Programs\Python\Pytho
# ...

# %% [markdown]
# ### Visualize Model Architecture with Computational Graph
#
# This code creates a visualization of the architecture of your deep learning model using the torchviz library. Here's how it works:
#
# 1. Model Initialization: A dummy instance of your model (`ConvNet`) is created.
# 2. Dummy Input: A dummy tensor of shape `(1, 3, 150, 150)` is generated to simulate a batch of images (1 image with 3 color channels and size 150x150).
# 3. Forward Pass: The dummy input is passed through the model to generate a computational graph.
# 4. Graph Visualization:The computational graph is then visualized and saved as a PNG image.
#
# The torchviz library uses `make_dot` to render the graph, which shows the model layers and operations performed during the forward pass.
#
# This helps to visualize the model architecture and understand its computational flow.
#
# The final image is saved as `model_architecture.png` and displayed directly in the notebook.

# %%
from torchviz import make_dot
import torch
from PIL import Image
import IPython.display as display

# Create an instance of your model
model = ConvNet(num_classes=2)

# Create a dummy input tensor with the expected shape
dummy_input = torch.randn(1, 3, 150, 150)

# Pass the dummy input through the model to generate a computational graph
output = model(dummy_input)

# Visualize the computational graph and save it as a PNG file
graph = make_dot(output, params=dict(model.named_parameters()))
graph.render("model_architecture", format="png", cleanup=True)

# Display the saved graph in the notebook
img = Image.open("model_architecture.png")
display.display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1281x1148>

# %% [markdown]
# ### Importing Libraries for Model and Data Processing

# %%
import os
import numpy as np
import torch
import glob
import torch.nn as nn
from torchvision.transforms import transforms
from torch.utils.data import DataLoader
from torch.optim import Adam
from torch.autograd import Variable
import torchvision

# %% [markdown]
# ### Data Augmentation Transformations

# %%
transformer = transforms.Compose([
    transforms.Resize((150, 150)),
    transforms.RandomHorizontalFlip(),  # Horizontal flip
    transforms.RandomVerticalFlip(),    # Vertical flip
    transforms.RandomRotation(20),      # Rotate ±20 degrees
    transforms.RandomAffine(degrees=0, scale=(0.8, 1.2)),  # Random zoom
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),  # Color variations
    transforms.ToTensor(),  # Convert to tensor
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])  # Normalize
])

# %% [markdown]
# Loading Training and Testing Data

# %%
train_path='D:/train2'
test_path='D:/split_test'

train_loader=DataLoader(
    torchvision.datasets.ImageFolder(train_path,transform=transformer),
    batch_size=64, shuffle=True
)
test_loader=DataLoader(
    torchvision.datasets.ImageFolder(test_path,transform=transformer),
    batch_size=32, shuffle=True
)

# %% [markdown]
# ### Retrieving Class Names from Training Data Directory

# %%
import pathlib

# Assuming train_path is the path to the training data directory
train_path = 'D:/train2'  # Replace with the actual path to your training data

# Get all class names (subdirectories) in the train directory
root = pathlib.Path(train_path)
classes = sorted([folder.name for folder in root.iterdir() if folder.is_dir()])

# Print the classes
print(classes)
# Out:
# ['notheft_color', 'theft_color']

# %%
print(classes)
# Out:
# ['notheft_color', 'theft_color']

# %% [markdown]
# ### Convolutional Neural Network (ConvNet) Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ConvNet(nn.Module):
    def __init__(self, num_classes=2):  # Binary classification
        super(ConvNet, self).__init__()
        
        # First convolutional layer - reduced filters
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=8, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(num_features=8)
        self.relu1 = nn.ReLU()
        
        # Pooling layer
        self.pool = nn.MaxPool2d(kernel_size=2)  # Reduces spatial dimensions by half
        
        # Second convolutional layer - reduced filters
        self.conv2 = nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(num_features=16)
        self.relu2 = nn.ReLU()
        
        # Add a second pooling layer
        self.pool2 = nn.MaxPool2d(kernel_size=2)
        
        # Third convolutional layer - reduced filters
        self.conv3 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.bn3 = nn.BatchNorm2d(num_features=32)
        self.relu3 = nn.ReLU()
        
        # Add a third pooling layer
        self.pool3 = nn.MaxPool2d(kernel_size=2)
        
        # Dropout to reduce overfitting - increased dropout rate
        self.dropout = nn.Dropout(p=0.6)  # Increased dropout rate
        
        # Fully connected layer - adjusted input size due to smaller feature maps
        self.fc = nn.Linear(in_features=32 * 18 * 18, out_features=num_classes)  # Adjusted input size

    def forward(self, input):
        # First convolutional layer
        output = self.conv1(input)
        output = self.bn1(output)
        output = self.relu1(output)
        output = self.pool(output)
        
        # Second convolutional layer
        output = self.conv2(output)
        output = self.bn2(output)
        output = self.relu2(output)
        output = self.pool2(output)
        
        # Third convolutional layer
        output = self.conv3(output)
        output = self.bn3(output)
        output = self.relu3(output)
        output = self.pool3(output)
        
        # Apply dropout
        output = self.dropout(output)
        
        # Flatten the tensor
        output = output.view(-1, 32 * 18 * 18)  # Adjusted for pooling layers
        
        # Fully connected layer
        output = self.fc(output)
        
        return output

# %% [markdown]
# ## Install torchsummary Library

# %%
# !pip install torchsummary
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Display Model Summary Using torchsummary

# %%
from torchsummary import summary
import torch

# Instantiate your model
model = ConvNet(num_classes=2)

# Set the model to evaluation mode (important for correct summary generation)
model.eval()

# Provide a dummy input to the summary function
dummy_input = torch.randn(1, 3, 150, 150)  # 1 sample, 3 channels, 150x150 image

# Generate the summary
summary(model, input_size=(3, 150, 150))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1          [-1, 8, 150, 150]             224
#        BatchNorm2d-2          [-1, 8, 150, 150]              16
#               ReLU-3          [-1, 8, 150, 150]               0
#          MaxPool2d-4            [-1, 8, 75, 75]               0
#             Conv2d-5           [-1, 16, 75, 75]           1,168
#        BatchNorm2d-6           [-1, 16, 75, 75]              32
#               ReLU-7           [-1, 16, 75, 75]               0
#          MaxPool2d-8           [-1, 16, 37, 37]               0
#             Conv2d-9           [-1, 32, 37, 37]           4,640
#       BatchNorm2d-10           [-1, 32, 37, 37]              64
#              ReLU-11           [-1, 32, 37, 37]               0
#         MaxPool2d-12           [-1, 32, 18, 18]               0
#           Dropout-13           [-1, 32, 18, 18]               0
# ...

# %% [markdown]
# ### Check Device Availability and Move Model to GPU or CPU

# %%
import torch

# Check if GPU is available, otherwise use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Now, you can create the model and send it to the device
model = ConvNet(num_classes=6).to(device)

# %%
# Initialize model
model = ConvNet(num_classes=2).to(device)  # Ensure the model is on CPU

# %% [markdown]
# ### Set Number of Epochs for Training

# %%
num_epochs=30

# %% [markdown]
# ### Count Training and Testing Images

# %%
import glob
import os

# Use os.path.join to ensure correct path separators
train_path = 'D:/train2'
test_path = 'D:/split_test'

# Adjust the pattern to match files recursively and case insensitivity
train_count = len(glob.glob(os.path.join(train_path, '**', '*.jpg'), recursive=True))
test_count = len(glob.glob(os.path.join(test_path, '**', '*.jpg'), recursive=True))

print(f"Number of training images: {train_count}")
print(f"Number of testing images: {test_count}")
# Out:
# Number of training images: 12740
# Number of testing images: 5460

# %% [markdown]
# ### Training and Evaluation Code with Metrics

# %%
import torch
import torch.nn as nn
from torch.optim import Adam
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    average_precision_score,
    f1_score,
)
import numpy as np

# Set device to CPU (or GPU if available)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize model (ensure ConvNet is defined before this)
model = ConvNet(num_classes=2).to(device)  # Change num_classes to 2 (binary classification)

# Loss function and optimizer
class_weights = torch.tensor([1.0, 2.0]).to(device)  # Adjust for class imbalance if needed
loss_function = nn.CrossEntropyLoss(weight=class_weights)
optimizer = Adam(model.parameters(), lr=0.001, weight_decay=0.0001)

# Add a learning rate scheduler
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# Initialize best_accuracy variable
best_accuracy = 0.0

# Define the count of samples for training and testing
train_count = len(train_loader.dataset)
test_count = len(test_loader.dataset)

# For plotting accuracy curves and confusion matrix
train_accuracies = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    model.train()  # Set model to training mode
    train_accuracy = 0.0
    train_loss = 0.0
    
    for i, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device)
        
        optimizer.zero_grad()  # Zero the gradients
        
        outputs = model(images)  # Get model predictions
        loss = loss_function(outputs, labels)  # Calculate loss
        loss.backward()  # Backpropagate gradients
        optimizer.step()  # Update model parameters
        
        train_loss += loss.item() * images.size(0)
        _, prediction = torch.max(outputs.data, 1)
        train_accuracy += int(torch.sum(prediction == labels.data))
    
    train_accuracy = train_accuracy / train_count
    train_loss = train_loss / train_count

    # Test evaluation
    model.eval()  # Set model to evaluation mode
    test_accuracy = 0.0
    all_predictions = []
    all_labels = []
    all_probabilities = []
    
    with torch.no_grad():
        for i, (images, labels) in enumerate(test_loader):
            images = images.to(device)
            labels = labels.to(device)
            
            outputs = model(images)
            _, prediction = torch.max(outputs.data, 1)
            probabilities = torch.nn.functional.softmax(outputs, dim=1)
            
            test_accuracy += int(torch.sum(prediction == labels.data))
            all_predictions.extend(prediction.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            all_probabilities.extend(probabilities.cpu().numpy())
    
    test_accuracy = test_accuracy / test_count

    print(f'Epoch: {epoch} Train Loss: {train_loss:.4f} Train Accuracy: {train_accuracy:.4f} Test Accuracy: {test_accuracy:.4f}')
    
    train_accuracies.append(train_accuracy)
    test_accuracies.append(test_accuracy)
    
    if test_accuracy > best_accuracy:
        torch.save(model.state_dict(), 'best_checkpoint.model')
        best_accuracy = test_accuracy
    
    scheduler.step()

torch.save(model.state_dict(), 'final_model.pth')

# Plotting Training and Testing Accuracy
plt.figure(figsize=(10, 6))
plt.plot(range(num_epochs), train_accuracies, label='Train Accuracy', color='blue')
plt.plot(range(num_epochs), test_accuracies, label='Test Accuracy', color='red')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Confusion Matrix (Normalized)
cm = confusion_matrix(all_labels, all_predictions, normalize='true')
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt=".2f", cmap="Blues", xticklabels=['No Theft', 'Theft'], yticklabels=['No Theft', 'Theft'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Normalized Confusion Matrix')
plt.show()

# Classification Report
print("Classification Report:")
print(classification_report(all_labels, all_predictions, target_names=["No Theft", "Theft"]))

# F1 Score
f1 = f1_score(all_labels, all_predictions, average='weighted')  # Weighted F1 for imbalance
print(f"Weighted F1 Score: {f1:.4f}")

# ROC Curve and AUC
positive_probabilities = [prob[1] for prob in all_probabilities]
fpr, tpr, _ = roc_curve(all_labels, positive_probabilities)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(10, 6))
plt.plot(fpr, tpr, color="blue", lw=2, label=f"ROC curve (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], color="gray", lw=2, linestyle="--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC Curve)")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# Precision-Recall Curve and Average Precision Score
precision, recall, _ = precision_recall_curve(all_labels, positive_probabilities)
average_precision = average_precision_score(all_labels, positive_probabilities)

plt.figure(figsize=(10, 6))
plt.plot(
    recall,
    precision,
    color="green",
    lw=2,
    label=f"PR curve (AP = {average_precision:.2f})",
)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend(loc="lower left")
plt.grid(True)
plt.show()

# Print Summary Metrics
print(f"ROC AUC Score: {roc_auc:.2f}")
print(f"Average Precision Score: {average_precision:.2f}")
# Out:
# Epoch: 0 Train Loss: 0.7034 Train Accuracy: 0.6183 Test Accuracy: 0.6372
# Epoch: 1 Train Loss: 0.5994 Train Accuracy: 0.6687 Test Accuracy: 0.6879
# Epoch: 2 Train Loss: 0.5357 Train Accuracy: 0.7074 Test Accuracy: 0.5258
# Epoch: 3 Train Loss: 0.4815 Train Accuracy: 0.7364 Test Accuracy: 0.5590
# Epoch: 4 Train Loss: 0.4336 Train Accuracy: 0.7628 Test Accuracy: 0.5641
# Epoch: 5 Train Loss: 0.4218 Train Accuracy: 0.7727 Test Accuracy: 0.6828
# Epoch: 6 Train Loss: 0.3761 Train Accuracy: 0.8057 Test Accuracy: 0.6875
# Epoch: 7 Train Loss: 0.3749 Train Accuracy: 0.8013 Test Accuracy: 0.6707
# Epoch: 8 Train Loss: 0.3462 Train Accuracy: 0.8198 Test Accuracy: 0.6557
# Epoch: 9 Train Loss: 0.3301 Train Accuracy: 0.8312 Test Accuracy: 0.6161
# Epoch: 10 Train Loss: 0.2861 Train Accuracy: 0.8549 Test Accuracy: 0.6804
# Epoch: 11 Train Loss: 0.2718 Train Accuracy: 0.8681 Test Accuracy: 0.6833
# Epoch: 12 Train Loss: 0.2622 Train Accuracy: 0.8734 Test Accuracy: 0.6881
# ...

# %% [markdown]
# ### Model Saving and Loading Code

# %%
torch.save(model.state_dict(), 'final_model.pth')


model = ConvNet(num_classes=2)  # Recreate the model architecture
model.load_state_dict(torch.load('final_model.pth', weights_only=True))
model.eval()  # Set the model to evaluation mode

model.load_state_dict(torch.load('final_model.pth', weights_only=True))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### Model Prediction and Evaluation Code

# %%
import torch

# Set device to CPU (or GPU if available)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load the saved model
model = ConvNet(num_classes=2).to(device)  # Ensure this matches your trained model
model.load_state_dict(torch.load('final_model.pth'))  # Load saved weights
model.eval()  # Set model to evaluation mode

# Define class labels
class_labels = {0: "no-theft", 1: "theft"}  # Adjust labels if needed

# Function to predict a single image
def predict_image(image, model, device):
    image = image.to(device)  # Move image to device
    image = image.unsqueeze(0)  # Add batch dimension (1, C, H, W)
    with torch.no_grad():
        outputs = model(image)  # Get predictions
        _, predicted_class = torch.max(outputs, 1)  # Get the class with the highest score
    return predicted_class.item()  # Return class index

# Initialize counters for evaluation
correct_predictions = 0
total_predictions = 0

# Loop through your test_loader to predict and evaluate images
for images, labels in test_loader:
    for i in range(images.size(0)):  # Loop through each image in the batch
        image = images[i]
        true_label = labels[i].item()  # True label for comparison
        predicted_class = predict_image(image, model, device)
        predicted_label = class_labels[predicted_class]  # Map class index to label

        # Print predictions and true labels
        print(f"Image {total_predictions + 1}: Predicted = {predicted_label}, True = {class_labels[true_label]}")

        # Check if the prediction is correct
        if predicted_class == true_label:
            correct_predictions += 1
        else:
            print(f"**Incorrect Prediction!** Predicted = {predicted_label}, True = {class_labels[true_label]}")
        
        total_predictions += 1

# Print overall evaluation metrics
accuracy = (correct_predictions / total_predictions) * 100
print("\n--- Evaluation Summary ---")
print(f"Total Images: {total_predictions}")
print(f"Correct Predictions: {correct_predictions}")
print(f"Incorrect Predictions: {total_predictions - correct_predictions}")
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# C:\Users\ARAVINDA S H\AppData\Local\Temp\ipykernel_5388\1711696533.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %% [markdown]
# ### Model Prediction and Visualizing Examples

# %%
import torch
import matplotlib.pyplot as plt
from torchvision.transforms.functional import to_pil_image
import numpy as np

# Define function for denormalizing images
def denormalize(tensor, mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)):
   
    mean = torch.tensor(mean).view(1, 3, 1, 1)  # Match shape for broadcasting
    std = torch.tensor(std).view(1, 3, 1, 1)   # Match shape for broadcasting
    return tensor * std + mean

# Initialize examples to store specific cases
examples = {
    "True = No Theft, Predicted = No Theft": None,
    "True = Theft, Predicted = Theft": None,
    "True = No Theft, Predicted = Theft": None,
    "True = Theft, Predicted = No Theft": None
}

# Loop through the test dataset and save examples for each case
for images, labels in test_loader:
    for i in range(images.size(0)):
        image = images[i]
        true_label = labels[i].item()
        predicted_class = predict_image(image, model, device)

        # Determine the case for the current image
        if true_label == 0 and predicted_class == 0 and examples["True = No Theft, Predicted = No Theft"] is None:
            examples["True = No Theft, Predicted = No Theft"] = (image, "True = No Theft, Predicted = No Theft")
        elif true_label == 1 and predicted_class == 1 and examples["True = Theft, Predicted = Theft"] is None:
            examples["True = Theft, Predicted = Theft"] = (image, "True = Theft, Predicted = Theft")
        elif true_label == 0 and predicted_class == 1 and examples["True = No Theft, Predicted = Theft"] is None:
            examples["True = No Theft, Predicted = Theft"] = (image, "True = No Theft, Predicted = Theft")
        elif true_label == 1 and predicted_class == 0 and examples["True = Theft, Predicted = No Theft"] is None:
            examples["True = Theft, Predicted = No Theft"] = (image, "True = Theft, Predicted = No Theft")

        # Break the loop once all cases are covered
        if all(v is not None for v in examples.values()):
            break
    if all(v is not None for v in examples.values()):
        break

# Plot the examples
plt.figure(figsize=(12, 8))
plot_index = 1

for case, (image, title) in examples.items():
    if image is not None:
        # De-normalize and prepare the image for visualization
        image = denormalize(image.unsqueeze(0))  # Add batch dimension for broadcasting
        image = image.squeeze(0)  # Remove batch dimension for PIL conversion
        image = image.clamp(0, 1)  # Ensure pixel values are in [0, 1]
        image = to_pil_image(image)  # Convert to PIL image for better rendering
        
        # Plot the image
        plt.subplot(2, 2, plot_index)
        plt.imshow(image)
        plt.title(title, fontsize=12)
        plt.axis('off')
        plot_index += 1

plt.tight_layout()
plt.show()

# %%
import torch
import matplotlib.pyplot as plt
from torchvision.transforms.functional import to_pil_image
import numpy as np

# Define function for denormalizing images
def denormalize(tensor, mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)):
  
    mean = torch.tensor(mean).view(1, 3, 1, 1)  # Match shape for broadcasting
    std = torch.tensor(std).view(1, 3, 1, 1)   # Match shape for broadcasting
    return tensor * std + mean

# Initialize examples to store specific cases
examples = {
    "True = No Theft, Predicted = No Theft": None,
    "True = Theft, Predicted = Theft": None,
    "True = No Theft, Predicted = Theft": None,
    "True = Theft, Predicted = No Theft": None
}

# Loop through the test dataset and save examples for each case
for images, labels in test_loader:
    for i in range(images.size(0)):
        image = images[i]
        true_label = labels[i].item()
        predicted_class = predict_image(image, model, device)

        # Determine the case for the current image
        if true_label == 0 and predicted_class == 0 and examples["True = No Theft, Predicted = No Theft"] is None:
            examples["True = No Theft, Predicted = No Theft"] = (image, "True = No Theft, Predicted = No Theft")
        elif true_label == 1 and predicted_class == 1 and examples["True = Theft, Predicted = Theft"] is None:
            examples["True = Theft, Predicted = Theft"] = (image, "True = Theft, Predicted = Theft")
        elif true_label == 0 and predicted_class == 1 and examples["True = No Theft, Predicted = Theft"] is None:
            examples["True = No Theft, Predicted = Theft"] = (image, "True = No Theft, Predicted = Theft")
        elif true_label == 1 and predicted_class == 0 and examples["True = Theft, Predicted = No Theft"] is None:
            examples["True = Theft, Predicted = No Theft"] = (image, "True = Theft, Predicted = No Theft")

        # Break the loop once all cases are covered
        if all(v is not None for v in examples.values()):
            break
    if all(v is not None for v in examples.values()):
        break

# Plot the examples
plt.figure(figsize=(12, 8))
plot_index = 1

for case, (image, title) in examples.items():
    if image is not None:
        # De-normalize and prepare the image for visualization
        image = denormalize(image.unsqueeze(0))  # Add batch dimension for broadcasting
        image = image.squeeze(0)  # Remove batch dimension for PIL conversion
        image = image.clamp(0, 1)  # Ensure pixel values are in [0, 1]
        image = to_pil_image(image)  # Convert to PIL image for better rendering
        
        # Plot the image
        plt.subplot(2, 2, plot_index)
        plt.imshow(image)
        plt.title(title, fontsize=12)
        plt.axis('off')
        plot_index += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Predicting, Saving, and Sending Email Alerts for Theft Detection

# %%
import torch
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders
import os
from datetime import datetime
import torchvision
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# Set device to CPU (or GPU if available)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load the saved model
model = ConvNet(num_classes=2).to(device)  # Ensure this matches your trained model
model.load_state_dict(torch.load('final_model.pth'))  # Load saved weights
model.eval()  # Set model to evaluation mode

# Define class labels
class_labels = {0: "no-theft", 1: "theft"}  # Adjust labels if needed

# Function to predict a single image
def predict_image(image, model, device):
    image = image.to(device)  # Move image to device
    image = image.unsqueeze(0)  # Add batch dimension (1, C, H, W)
    with torch.no_grad():
        outputs = model(image)  # Get predictions
        _, predicted_class = torch.max(outputs, 1)  # Get the class with the highest score
    return predicted_class.item()  # Return class index

# Function to send an email alert
def send_alert_email(image_path, confidence_score, timestamp, frame_name):
    sender_email = "aditiaravinda2203@gmail.com"  # Your email address
    receiver_email = "1rn21ec005.aditisaravinda@gmail.com"  # Receiver's email address
    password = "ajmp bkff jiqr qktq"  # Replace with your generated app password

    # Create email
    message = MIMEMultipart()
    message['From'] = sender_email
    message['To'] = receiver_email
    message['Subject'] = f"Alert: Theft Detected in Frame {frame_name}!"
    
    # Email body
    body = (
        f"Dear User,\n\n"
        f"A potential theft has been detected with a confidence score of {confidence_score:.2f}.\n"
        f"Timestamp: {timestamp}\n\n"
        f"Please find the attached image for verification.\n\n"
        f"Regards,\nSecurity Team"
    )
    message.attach(MIMEText(body, 'plain'))
    
    # Attach the detected image
    with open(image_path, "rb") as attachment:
        part = MIMEBase('application', 'octet-stream')
        part.set_payload(attachment.read())
        encoders.encode_base64(part)
        part.add_header(
            "Content-Disposition",
            f"attachment; filename={os.path.basename(image_path)}",
        )
        message.attach(part)
    
    # Send the email
    try:
        with smtplib.SMTP('smtp.gmail.com', 587) as server:
            server.starttls()  # Secure the connection
            server.login(sender_email, password)  # Login with your app password
            server.send_message(message)
            print(f"Alert email sent for frame: {frame_name}")
    except Exception as e:
        print(f"Failed to send email: {e}")

# Initialize counter
total_predictions = 0

# Directory for saving detected images
output_dir = "detected_images"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Loop through your test_loader to predict and evaluate images
for images, labels in test_loader:
    for i in range(images.size(0)):  # Loop through each image in the batch
        if total_predictions >= 3500:  # Stop after processing 3500 frames
            break

        image = images[i]
        true_label = labels[i].item()  # True label for comparison
        predicted_class = predict_image(image, model, device)
        predicted_label = class_labels[predicted_class]  # Map class index to label

        # Print predictions and true labels
        print(f"Image {total_predictions + 1}: Predicted = {predicted_label}, True = {class_labels[true_label]}")

        total_predictions += 1
        
        # Only send email if both predicted and true labels are "theft"
        if predicted_class == 1 and true_label == 1:  # If theft is predicted and true
            confidence_score = 1.0  # Assuming maximum confidence for true theft detections
            frame_name = f"frame_{total_predictions}.jpg"  # Create unique name for the frame
            timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
            
            # Save the detected image
            image_path = os.path.join(output_dir, f"theft_{frame_name}")
            torchvision.utils.save_image(image.cpu(), image_path)

            # Send email alert
            send_alert_email(image_path, confidence_score, timestamp, frame_name)

    if total_predictions >= 3500:  # Break the outer loop as well
        break
# Out:
# C:\Users\ARAVINDA S H\AppData\Local\Temp\ipykernel_19020\2582865433.py:18: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...
